# %% [markdown]
# # Title:Amazon data analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('amazon.csv',encoding='utf-8')

# %%
df
df2=df.copy()

# %% [markdown]
# ## data cleaning

# %%
df['discounted_price']=df['discounted_price'].replace('[^0-9.]','',regex=True).astype(float)

# %%
df['actual_price']=df['actual_price'].replace('[^0-9.]','',regex=True).astype(float)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %% [markdown]
# ## data analysis

# %%
df.sort_values(by='discounted_price',ascending=False).head(10)
# Out:
#       product_id                                       product_name  \
# 249   B09WN3SRC7  Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...
# 325   B095JPKPH3  OnePlus 163.8 cm (65 inches) U Series 4K LED S...
# 255   B0BC8BQ432  VU 164 cm (65 inches) The GloLED Series 4K Sma...
# 192   B0B15GSPQW  Samsung 138 cm (55 inches) Crystal 4K Neo Seri...
# 283   B0B3XXSB1K  LG 139 cm (55 inches) 4K Ultra HD Smart LED TV...
# 332   B09RWQ7YR6  MI 138.8 cm (55 inches) 5X Series 4K Ultra HD ...
# 276   B092BL5DCX  Samsung 138 cm (55 inches) Crystal 4K Series U...
# 533   B0B5V47VK4  OnePlus 10T 5G (Moonstone Black, 8GB RAM, 128G...
# 216   B095JQVC7N  OnePlus 138.7 cm (55 inches) U Series 4K LED S...
# 1354  B09NS5TKPN  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
#
#                                                category  discounted_price  \
# 249   Electronics|HomeTheater,TV&Video|Televisions|S...           77990.0
# ...

# %%
df.sort_values(by='discounted_price',ascending=True).head(10)
# Out:
#      product_id                                       product_name  \
# 645  B00MFPCY5C  GIZGA essentials Universal Silicone Keyboard P...
# 975  B08TDJ5BVF  E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...
# 997  B00URH5E34  Inventis 5V 1.2W Portable Flexible USB LED Lig...
# 616  B07KCMR8D6  Classmate Octane Neon- Blue Gel Pens(Pack of 5...
# 178  B0B3MQXNFB  FLiX (Beetel Flow USB to Micro USB PVC Data Sy...
# 44   B09NJN8L25  FLiX (Beetel USB to Micro USB PVC Data Sync & ...
# 478  B09NHVCHS9        Flix Micro Usb Cable For Smartphone (Black)
# 23   B09NHVCHS9        Flix Micro Usb Cable For Smartphone (Black)
# 710  B08TDJNM3G  E-COSMOS 5V 1.2W Portable Flexible USB LED Lig...
# 727  B09NHVCHS9        Flix Micro Usb Cable For Smartphone (Black)
#
#                                               category  discounted_price  \
# 645  Computers&Accessories|Accessories&Peripherals|...             39.00
# 975  Computers&Accessories|Accessories&Peripherals|...             39.00
# ...

# %%
df['category'].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                        1
# ...

# %%
df.groupby('category').mean(numeric_only=True)
# Out:
#                                                     discounted_price  \
# category
# Car&Motorbike|CarAccessories|InteriorAccessorie...       2339.000000
# Computers&Accessories|Accessories&Peripherals|A...        221.500000
# Computers&Accessories|Accessories&Peripherals|A...        649.000000
# Computers&Accessories|Accessories&Peripherals|A...        574.000000
# Computers&Accessories|Accessories&Peripherals|A...        749.000000
# ...                                                              ...
# OfficeProducts|OfficePaperProducts|Paper|Statio...        150.000000
# OfficeProducts|OfficePaperProducts|Paper|Statio...        255.000000
# OfficeProducts|OfficePaperProducts|Paper|Statio...        329.000000
# OfficeProducts|OfficePaperProducts|Paper|Statio...        244.333333
# Toys&Games|Arts&Crafts|Drawing&PaintingSupplies...        150.000000
#
#                                                     actual_price
# category
# ...

# %%
df['discount_percentage']=df['discount_percentage'].str.rstrip('%').astype(float)/100.0

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df.groupby('category')['discount_percentage'].mean()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    0.420
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   0.785
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           0.350
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        0.565
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           0.465
#                                                                                                                           ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        0.000
# ...

# %%
df['main_category']=df['category'].str.split('|').str[0]

# %%
avg_dis_prec=df.groupby('main_category')['discount_percentage'].mean()

# %%
avg_dis_prec.sort_values(ascending=False)
# Out:
# main_category
# HomeImprovement          0.575000
# Computers&Accessories    0.540243
# Health&PersonalCare      0.530000
# Electronics              0.508289
# MusicalInstruments       0.460000
# Car&Motorbike            0.420000
# Home&Kitchen             0.401205
# OfficeProducts           0.123548
# Toys&Games               0.000000
# Name: discount_percentage, dtype: float64

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# ...

# %%
df['discount_percentage']
# Out:
# 0       0.64
# 1       0.43
# 2       0.90
# 3       0.53
# 4       0.61
#         ...
# 1460    0.59
# 1461    0.25
# 1462    0.28
# 1463    0.26
# 1464    0.22
# Name: discount_percentage, Length: 1465, dtype: float64

# %%
df.groupby('main_category').mean(numeric_only=True)
# Out:
#                        discounted_price  actual_price  discount_percentage
# main_category
# Car&Motorbike               2339.000000   4000.000000             0.420000
# Computers&Accessories        842.650375   1683.623135             0.540243
# Electronics                 5965.887833  10127.311787             0.508289
# Health&PersonalCare          899.000000   1900.000000             0.530000
# Home&Kitchen                2330.615647   4162.073661             0.401205
# HomeImprovement              337.000000    799.000000             0.575000
# MusicalInstruments           638.000000   1347.000000             0.460000
# OfficeProducts               301.580645    397.193548             0.123548
# Toys&Games                   150.000000    150.000000             0.000000

# %%
df[['discount_percentage','rating']].dtypes
df['rating']=pd.to_numeric(df['rating'],errors='coerce')
df[['discount_percentage','rating']].corr()
# Out:
#                      discount_percentage    rating
# discount_percentage             1.000000 -0.155375
# rating                         -0.155375  1.000000

# %%
avg_dis_prec=df['discounted_price'].mean()
avg_dis_prec
# Out:
# np.float64(3125.3108737201364)

# %%
df_best_product=df[(df['rating']>=4) & (df['discounted_price']<=avg_dis_prec)]

# %%
df_best_product
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 6     B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# ...          ...                                                ...
# 1457  B00TI8E7BI  Philips HD9306/06 1.5-Litre Electric Kettle (M...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...            399.00
# ...

# %%
df['main_category'].value_counts().plot(kind='bar',xlabel='category',ylabel='no of products')
# Out:
# <Axes: xlabel='category', ylabel='no of products'>

# %%
df['discounted_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby('main_category')['discount_percentage'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='main_category'>

# %%
#Insight 1: Category Discounts
#WHAT:
#HomeImprovement has the highest average discount (~57%), while Toys & Games has almost no discount.

#WHY:
#HomeImprovement products are mid-priced and allow flexible pricing strategies,
#while Toys & Games are already low-cost items with limited margins, making discounts less necessary.

#SO WHAT:
#This suggests that companies can use high-discount categories like HomeImprovement to
#attract price-sensitive customers, while maintaining stable pricing in low-margin categories
#like Toys & Games.

# %%
#insight 2
#what:Computers&Accessories has best value products more then other category
#toys and games has less best value products
#why:because Computers&Accessories are basic needs ,
#having 2nd largest avg discount after homeimprovements,
#so making themcheaper to buy
#so what:this tells that computer and assessories have high rating with less price so selling them is
#easy

# %%
#insight 3
#what:here discount_precntage and rating has negative number i.e -0.155375
#but the negative is less so i cant say that they r not related directly
#why
#well dicount is seen by user before purchasing the product and rating is done after purchasing the 
#product so i can say that rating depends on customer experience with the product not no discount
#what so: company shd not assume that if they give more discount they will have more rating for the product

# %%
#Insight 4.business recommendations
#what: here we should focus on promoting  Computers&Accessories  and  Electronics .
#dicount and rating has weak negative nuber as corellation.
#why so: Computers&Accessories has the highest best value product so promoting them more can increase
#the sells and  Electronics has high margin even after discount so promoting them help company
#make more profit also discount and rating has no relation
#what so:sell Computers&Accessories and Electronics to balance volume and profit
